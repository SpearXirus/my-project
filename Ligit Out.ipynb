# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/spear/Downloads/GWANGJIN_SMART_LIGHT_2022.12.26-01.01.csv', encoding='CP949')

# %%
df1
# Out:
#                          기관 명  모델명  시리얼  접속간격  수동유지  지역ID 점등편차  소등편차  \
# 광진구 BMC-300S  019010d00000fd0  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00000d92  120   10     1   -20    13   XX     0
#     BMC-300S  019010d0000ad42  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00006157  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00005b57  120   10     1   -20    13   XX     0
# ...                       ...  ...  ...   ...   ...   ...  ...   ...
#     BMC-300S  019010d0000ad83  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00000f93  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00009290  120   10     1   -20    13   XX     0
#     BMC-300S  019010d0000d792  120   10     1   -20    13   XX     0
#     BMC-300S  019010d000074fd  120   10     1   -20    13   XX     0
#
#               심야소등시작시간  심야소등시작분  ...  현재디밍값(%) 현재전력값(W)  램프고장(정상:0, 고장:1)  \
# ...

# %%
df2 = pd.read_csv('C:/Users/spear/Downloads/GWANGJIN_SMART_LIGHT_2023.01.02-01.08.csv', encoding='CP949')
df3 = pd.read_csv('C:/Users/spear/Downloads/GWANGJIN_SMART_LIGHT_2023.01.09-01.15.csv', encoding='CP949')
df4 = pd.read_csv('C:/Users/spear/Downloads/GWANGJIN_SMART_LIGHT_2023.01.16-01.22.csv', encoding='CP949')
df5 = pd.read_csv('C:/Users/spear/Downloads/GWANGJIN_SMART_LIGHT_2023.01.23-01.29.csv', encoding='CP949')

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df
# Out:
#                          기관 명  모델명  시리얼  접속간격  수동유지  지역ID 점등편차  소등편차  \
# 광진구 BMC-300S  019010d00000fd0  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00000d92  120   10     1   -20    13   XX     0
#     BMC-300S  019010d0000ad42  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00006157  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00005b57  120   10     1   -20    13   XX     0
# ...                       ...  ...  ...   ...   ...   ...  ...   ...
#     BMC-300S  019010d0000b5f6  120   10     1   -20    13   XX     0
#     BMC-300S  019010d0000e08c  120   10     1   -20    13   XX     0
#     BMC-300S  019010d0000107f  120   10     1   -20    13   XX     0
#     BMC-300S  019010d0000103f  120   10     1   -20    13   XX     0
#     BMC-300S  019010d00005bc3  120   10     1   -20    13   XX     0
#
#               심야소등시작시간  심야소등시작분  ...  현재디밍값(%) 현재전력값(W)  램프고장(정상:0, 고장:1)  \
# ...

# %%
df.describe()
# Out:
#             모델명            시리얼      접속간격           수동유지           지역ID  \
# count  991511.0  991511.000000  991511.0  991511.000000  991511.000000
# mean      120.0       9.981451       1.0     -19.958897      13.076389
# std         0.0       0.431284       0.0       2.070825       1.692735
# min       120.0       1.000000       1.0     -79.000000     -15.000000
# 25%       120.0      10.000000       1.0     -20.000000      13.000000
# 50%       120.0      10.000000       1.0     -20.000000      13.000000
# 75%       120.0      10.000000       1.0     -20.000000      13.000000
# max       120.0      14.000000       1.0     -15.000000      60.000000
#
#            소등편차       심야소등시작시간   심야소등시작분      심야소등해제시간       심야소등적용기간  ...  \
# count  991511.0  991511.000000  991511.0  9.915110e+05  991511.000000  ...
# mean        0.0       0.003351       0.0  1.015703e+06       0.000372  ...
# std         0.0       0.100225       0.0  1.637349e+05       0.019288  ...
# ...
