# %%
# import
import pandas as pd
import folium
import requests
from urllib.parse import quote
import json

# %%
road_api = 'devU01TX0FVVEgyMDIyMTIyOTE2NTgxMTExMzM4NzA='
kakao_api = 'c6fb0ac29226c99411f33661deb221d4'

# %%
my_gohyang=['영등포구청', '구로구청', '서초구청', '양천구청']

# %%
my_go_addr=[]
for i in my_gohyang:
    base_url = 'https://business.juso.go.kr/addrlink/addrLinkApi.do'
    params1 = f'currentPage=1&countPerPage=10&confmKey={road_api}'
    params2 = f'keyword={quote(i)}&resultType=json'
    url = f'{base_url}?{params1}&{params2}'
    result = requests.get(url)
    res = json.loads(result.text)
    my_go_addr.append(res['results']['juso'][0]['roadAddr'])
my_go_addr
# Out:
# ['서울특별시 영등포구 당산로 지하121(당산동3가)',
#  '서울특별시 구로구 가마산로 245(구로동)',
#  '서울특별시 서초구 남부순환로 2584(서초동)',
#  '서울특별시 양천구 목동동로 105(신정동)']

# %%
df=pd.DataFrame({'장소':my_gohyang,'도로명주소':my_go_addr})
df
# Out:
#       장소                        도로명주소
# 0  영등포구청  서울특별시 영등포구 당산로 지하121(당산동3가)
# 1   구로구청      서울특별시 구로구 가마산로 245(구로동)
# 2   서초구청    서울특별시 서초구 남부순환로 2584(서초동)
# 3   양천구청      서울특별시 양천구 목동동로 105(신정동)

# %%
uidos=[]
gyeongdoes=[]
for i in range(4):
    addr = df.iloc[i,1]
    search_url = 'https://dapi.kakao.com/v2/local/search/address.json'
    url2 = f'{search_url}?query={quote(addr)}'
    result2 = requests.get(url2,
                     headers={'Authorization': f'KakaoAK {kakao_api}'}).json()
    uidos.append(result2['documents'][0]['address']['y'])
    gyeongdoes.append(result2['documents'][0]['address']['x'])
print(uidos)
print(gyeongdoes)
# Out:
# ['37.5256996614804', '37.4955054632154', '37.4836248649455', '37.5170753784215']
# ['126.896626898379', '126.888292375229', '127.032683002019', '126.866542541936']

# %%
df['위도']=uidos
df['경도']=gyeongdoes
df
# Out:
#       장소                        도로명주소                위도                경도
# 0  영등포구청  서울특별시 영등포구 당산로 지하121(당산동3가)  37.5256996614804  126.896626898379
# 1   구로구청      서울특별시 구로구 가마산로 245(구로동)  37.4955054632154  126.888292375229
# 2   서초구청    서울특별시 서초구 남부순환로 2584(서초동)  37.4836248649455  127.032683002019
# 3   양천구청      서울특별시 양천구 목동동로 105(신정동)  37.5170753784215  126.866542541936

# %%
seoul_map = folium.Map(location=[37.55,126.96],zoom_start=12)
for name, lat, lng in zip(df.장소,df.위도,df.경도):
    folium.Marker([lat,lng],popup=name).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4edcf3c7c2dcbabe85f3b4fc49f31240 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4edcf3c7c2dcbabe85f3b4fc49f31240&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4edcf3c7c2dcbabe85f3b4fc49f31240 = L.map(
#                 &quot;map_4edcf3c7c2dcbabe85f3b4fc49f31240&quot;,
#                 {
#                     center: [37.55, 126.96],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a12b54416b6fc65e26fd20e1e7bd83bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4edcf3c7c2dcbabe85f3b4fc49f31240);
#
#
#             var marker_3fee3e5eb1a0197e4a0b31cfb95549aa = L.marker(
#                 [37.5256996614804, 126.896626898379],
#                 {}
#             ).addTo(map_4edcf3c7c2dcbabe85f3b4fc49f31240);
#
#
#         var popup_8a5901877bd86259e52872228f813898 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_039ff5938b0de81a05d90c08edb0df1d = $(`&lt;div id=&quot;html_039ff5938b0de81a05d90c08edb0df1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영등포구청&lt;/div&gt;`)[0];
#             popup_8a5901877bd86259e52872228f813898.setContent(html_039ff5938b0de81a05d90c08edb0df1d);
#
#
#         marker_3fee3e5eb1a0197e4a0b31cfb95549aa.bindPopup(popup_8a5901877bd86259e52872228f813898)
#         ;
#
#
#
#
#             var marker_2e584cd0f4b53850277d196dee426990 = L.marker(
#                 [37.4955054632154, 126.888292375229],
#                 {}
#             ).addTo(map_4edcf3c7c2dcbabe85f3b4fc49f31240);
#
#
#         var popup_fac556e00b9c5903f08544ab6c54e6fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_eee520ffc1c1c8abcb9fbcaa79b64d6f = $(`&lt;div id=&quot;html_eee520ffc1c1c8abcb9fbcaa79b64d6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;구로구청&lt;/div&gt;`)[0];
#             popup_fac556e00b9c5903f08544ab6c54e6fd.setContent(html_eee520ffc1c1c8abcb9fbcaa79b64d6f);
#
#
#         marker_2e584cd0f4b53850277d196dee426990.bindPopup(popup_fac556e00b9c5903f08544ab6c54e6fd)
#         ;
#
#
#
#
#             var marker_3d0b7b6e6db8a64ea8db464c4c0a080a = L.marker(
#                 [37.4836248649455, 127.032683002019],
#                 {}
#             ).addTo(map_4edcf3c7c2dcbabe85f3b4fc49f31240);
#
#
#         var popup_06393e430a75d69250589817578ebb75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a6f803ef35529f493c86d8d87e95709e = $(`&lt;div id=&quot;html_a6f803ef35529f493c86d8d87e95709e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구청&lt;/div&gt;`)[0];
#             popup_06393e430a75d69250589817578ebb75.setContent(html_a6f803ef35529f493c86d8d87e95709e);
#
#
#         marker_3d0b7b6e6db8a64ea8db464c4c0a080a.bindPopup(popup_06393e430a75d69250589817578ebb75)
#         ;
#
#
#
#
#             var marker_b03bbd5d0d3ed7891133239a482ea73b = L.marker(
#                 [37.5170753784215, 126.866542541936],
#                 {}
#             ).addTo(map_4edcf3c7c2dcbabe85f3b4fc49f31240);
#
#
#         var popup_b0210c588d81167f23a074c1fd7d04c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f2c20776b8d41eb3ba1a7f1cb081d9a9 = $(`&lt;div id=&quot;html_f2c20776b8d41eb3ba1a7f1cb081d9a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;양천구청&lt;/div&gt;`)[0];
#             popup_b0210c588d81167f23a074c1fd7d04c0.setContent(html_f2c20776b8d41eb3ba1a7f1cb081d9a9);
#
#
#         marker_b03bbd5d0d3ed7891133239a482ea73b.bindPopup(popup_b0210c588d81167f23a074c1fd7d04c0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
busan='중구,서구,동구,영도구,부산진구,동래구,남구,북구,해운대구,사하구,금정구,강서구,연제구,수영구,사상구,기장군'
busan = busan.split(',')

# %%
busan_gu=[]
for i in busan:
    busan_gu.append(i+'청')
busan_gu
# Out:
# ['중구청',
#  '서구청',
#  '동구청',
#  '영도구청',
#  '부산진구청',
#  '동래구청',
#  '남구청',
#  '북구청',
#  '해운대구청',
#  '사하구청',
#  '금정구청',
#  '강서구청',
#  '연제구청',
#  '수영구청',
#  '사상구청',
#  '기장군청']

# %%
busan_gu_addr=[]
for i in busan_gu:
    base_url = 'https://business.juso.go.kr/addrlink/addrLinkApi.do'
    params1 = f'currentPage=1&countPerPage=10&confmKey={road_api}'
    params2 = f'keyword={quote(i)}&resultType=json'
    url = f'{base_url}?{params1}&{params2}'
    result = requests.get(url)
    res = json.loads(result.text)
    busan_gu_addr.append(res['results']['juso'][0]['roadAddr'])
busan_gu_addr
# Out:
# ['서울특별시 중구 창경궁로 17(예관동)',
#  '부산광역시 서구 구덕로 120(토성동4가)',
#  '대전광역시 동구 동구청로 147(가오동)',
#  '부산광역시 영도구 태종로 423(청학동)',
#  '부산광역시 부산진구 시민공원로 30(부암동)',
#  '부산광역시 동래구 온천천로359번길 70(낙민동)',
#  '부산광역시 남구 못골로 19(대연동)',
#  '부산광역시 북구 낙동대로1570번길 33(구포동)',
#  '부산광역시 해운대구 중동2로 11(중동)',
#  '부산광역시 사하구 낙동대로398번길 12(당리동)',
#  '부산광역시 금정구 작장2길 49(노포동)',
#  '서울특별시 강서구 남부순환로 208(외발산동)',
#  '부산광역시 연제구 연제로 2(연산동)',
#  '부산광역시 수영구 남천동로 100(남천동)',
#  '부산광역시 사상구 학감대로 242(감전동)',
#  '부산광역시 기장군 기장읍 기장대로 560']

# %%
df2=pd.DataFrame({'장소':busan_gu,'도로명주소':busan_gu_addr})
df2
# Out:
#        장소                        도로명주소
# 0     중구청        서울특별시 중구 창경궁로 17(예관동)
# 1     서구청      부산광역시 서구 구덕로 120(토성동4가)
# 2     동구청       대전광역시 동구 동구청로 147(가오동)
# 3    영도구청       부산광역시 영도구 태종로 423(청학동)
# 4   부산진구청     부산광역시 부산진구 시민공원로 30(부암동)
# 5    동래구청  부산광역시 동래구 온천천로359번길 70(낙민동)
# 6     남구청         부산광역시 남구 못골로 19(대연동)
# 7     북구청  부산광역시 북구 낙동대로1570번길 33(구포동)
# 8   해운대구청       부산광역시 해운대구 중동2로 11(중동)
# 9    사하구청  부산광역시 사하구 낙동대로398번길 12(당리동)
# 10   금정구청       부산광역시 금정구 작장2길 49(노포동)
# 11   강서구청    서울특별시 강서구 남부순환로 208(외발산동)
# 12   연제구청         부산광역시 연제구 연제로 2(연산동)
# 13   수영구청      부산광역시 수영구 남천동로 100(남천동)
# 14   사상구청      부산광역시 사상구 학감대로 242(감전동)
# 15   기장군청       부산광역시 기장군 기장읍 기장대로 560

# %%
uidos=[]
gyeongdoes=[]
for i in range(16):
    addr = df2.iloc[i,1]
    search_url = 'https://dapi.kakao.com/v2/local/search/address.json'
    url2 = f'{search_url}?query={quote(addr)}'
    result2 = requests.get(url2,
                     headers={'Authorization': f'KakaoAK {kakao_api}'}).json()
    uidos.append(result2['documents'][0]['address']['y'])
    gyeongdoes.append(result2['documents'][0]['address']['x'])
print(uidos)
print(gyeongdoes)
# Out:
# ['37.5641201543296', '35.0975415693233', '36.3120364990332', '35.0912174458851', '35.162830637421', '35.1963016682278', '35.1365159482778', '35.1968825080786', '35.1631399226568', '35.1045019580248', '35.2825622674907', '37.5468670862325', '35.1762117404623', '35.145370159138', '35.1525507231581', '35.2434815827191']
# ['126.998009728978', '129.023426158671', '127.45491664858', '129.067910492443', '129.05318830381', '129.093862084451', '129.084434570775', '128.990095451939', '129.163561263676', '128.974790181016', '129.092871732288', '126.820414204647', '129.07974560596', '129.112369419599', '128.991456131232', '129.222956025904']

# %%
df2['위도']=uidos
df2['경도']=gyeongdoes
df2
# Out:
#        장소                        도로명주소                위도                경도
# 0     중구청        서울특별시 중구 창경궁로 17(예관동)  37.5641201543296  126.998009728978
# 1     서구청      부산광역시 서구 구덕로 120(토성동4가)  35.0975415693233  129.023426158671
# 2     동구청       대전광역시 동구 동구청로 147(가오동)  36.3120364990332   127.45491664858
# 3    영도구청       부산광역시 영도구 태종로 423(청학동)  35.0912174458851  129.067910492443
# 4   부산진구청     부산광역시 부산진구 시민공원로 30(부암동)   35.162830637421   129.05318830381
# 5    동래구청  부산광역시 동래구 온천천로359번길 70(낙민동)  35.1963016682278  129.093862084451
# 6     남구청         부산광역시 남구 못골로 19(대연동)  35.1365159482778  129.084434570775
# 7     북구청  부산광역시 북구 낙동대로1570번길 33(구포동)  35.1968825080786  128.990095451939
# 8   해운대구청       부산광역시 해운대구 중동2로 11(중동)  35.1631399226568  129.163561263676
# 9    사하구청  부산광역시 사하구 낙동대로398번길 12(당리동)  35.1045019580248  128.974790181016
# 10   금정구청       부산광역시 금정구 작장2길 49(노포동)  35.2825622674907  129.092871732288
# 11   강서구청    서울특별시 강서구 남부순환로 208(외발산동)  37.5468670862325  126.820414204647
# 12   연제구청         부산광역시 연제구 연제로 2(연산동)  35.1762117404623   129.07974560596
# 13   수영구청      부산광역시 수영구 남천동로 100(남천동)   35.145370159138  129.112369419599
# 14   사상구청      부산광역시 사상구 학감대로 242(감전동)  35.1525507231581  128.991456131232
# 15   기장군청       부산광역시 기장군 기장읍 기장대로 560  35.2434815827191  129.222956025904

# %%
busan_map = folium.Map(location=[35.16,129.05],zoom_start=12)
for name, lat, lng in zip(df2.장소,df2.위도,df2.경도):
    folium.Marker([lat,lng],popup=name).add_to(busan_map)
busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9efae8a616ab9214e335f7bccb6199a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9efae8a616ab9214e335f7bccb6199a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9efae8a616ab9214e335f7bccb6199a6 = L.map(
#                 &quot;map_9efae8a616ab9214e335f7bccb6199a6&quot;,
#                 {
#                     center: [35.16, 129.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_636d28d4fa72f57e73a94c91efe223d3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9efae8a616ab9214e335f7bccb6199a6);
#
#
#             var marker_0b602df062e98dee3f708cea017084ee = L.marker(
#                 [37.5641201543296, 126.998009728978],
#                 {}
#             ).addTo(map_9efae8a616ab9214e335f7bccb6199a6);
#
#
#         var popup_4e34c73e55f8b8a75bb9fc89926bf624 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_82f87fe8ba74b1dd998ee4793d1d288f = $(`&lt;div id=&quot;html_82f87fe8ba74b1dd998ee4793d1d288f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;중구청&lt;/div&gt;`)[0];
#             popup_4e34c73e55f8b8a75bb9fc89926bf624.setContent(html_82f87fe8ba74b1dd998ee4793d1d288f);
#
#
#         marker_0b602df062e98dee3f708cea017084ee.bindPopup(popup_4e34c73e55f8b8a75bb9fc89926bf624)
#         ;
#
#
#
#
#             var marker_5ba782c9aeaae2876810a03ec169e2db = L.marker(
#                 [35.0975415693233, 129.023426158671],
#                 {}
#             ).addTo(map_9efae8a616ab9214e335f7bccb6199a6);
#
#
#         var popup_84ef3da4744f975b0453193a99d6d8e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1d2edeb79a03ff465a5ee14304662f7e = $(`&lt;div id=&quot;html_1d2edeb79a03ff465a5ee14304662f7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서구청&lt;/div&gt;`)[0];
#             popup_84ef3da4744f975b0453193a99d6d8e6.setContent(html_1d2edeb79a03ff465a5ee14304662f7e);
#
#
#         marker_5ba782c9aeaae2876810a03ec169e2db.bindPopup(popup_84ef3da4744f975b0453193a99d6d8e6)
#         ;
#
#
#
#
#             var marker_ae10afe5d563f12a42c034e5a2948e37 = L.marker(
#                 [36.3120364990332, 127.45491664858],
#                 {}
#             ).addTo(map_9efae8a616ab9214e335f7bccb6199a6);
#
#
#         var popup_db12cbe0bd53d74a12b233d92da124b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_14109f766361b6045a298720a7aeaefc = $(`&lt;div id=&quot;html_14109f766361b6045a298720a7aeaefc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동구청&lt;/div&gt;`)[0];
#             popup_db12cbe0bd53d74a12b233d92da124b9.setContent(html_14109f766361b6045a298720a7aeaefc);
#
#
#         marker_ae10afe5d563f12a42c034e5a2948e37.bindPopup(popup_db12cbe0bd53d74a12b233d92da124b9)
#         ;
#
#
#
#
#             var marker_42ad3eaba677a4c81b7dfa4cf99b62e0 = L.marker(
#                 [35.0912174458851, 129.067910492443],
#                 {}
#             ).addTo(map_9efae8a616ab9214e335f7bccb6199a6);
#
#
#         var popup_feeb229c5a94fa8b2b90b3d89830d140 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_20d1ce2f1903cfec777518e83bfb116b = $(`&lt;div id=&quot;html_20d1ce2f1903cfec777518e83bfb116b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영도구청&lt;/div&gt;`)[0];
#             popup_feeb229c5a94fa8b2b90b3d89830d140.setContent(html_20d1ce2f1903cfec777518e83bfb116b);
#
#
#         marker_42ad3eaba677a4c81b7dfa4cf99b62e0.bindPopup(popup_feeb229c5a94fa8b2b90b3d89830d140)
#         ;
#
#
#
#
#             var marker_2af3e792c3093247f79ffb8917b5cc40 = L.marker(
#                 [35.162830637421, 129.05318830381],
#                 {}
#             ).addTo(map_9efae8a616ab9214e335f7bccb6199a6);
#
#
#         var popup_03bd2e51c9f68fc78af01209e86b5ee3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1190ed6d1f78c292d1f449d07dd9c571 = $(`&lt;div id=&quot;html_1190ed6d1f78c292d1f449d07dd9c571&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산진구청&lt;/div&gt;`)[0];
#             popup_03bd2e51c9f68fc78af01209e86b5ee3.setContent(html_1190ed6d1f78c292d1f449d07dd9c571);
#
#
#         marker_2af3e792c3093247f79ffb8917b5cc40.bindPopup(popup_03bd2e51c9f68fc78af01209e86b5ee3)
#         ;
#
#
#
#
#             var marker_95f38278ece11f15d5ca3177680c05b9 = L.marker(
#                 [35.1963016682278, 129.093862084451],
#                 {}
#             ).addTo(map_9efae8a616ab9214e335f7bccb6199a6);
#
#
#         var popup_3012a3077678d2b4b917ecf1c2b82ed1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_effcc5cc0869b442864a9497a5b122b9 = $(`&lt;div id=&quot
